# %% [markdown]
# # Single Batch Stream
#
# One-directional batch flows. Storage changes in steps.
# Varies: direction (input/output) × storage level (0, 250, auto_offset).

# %%
import datetime
import os

# %load_ext autoreload
# %autoreload 2

from ethos_penalps.stream import StreamType
from ethos_penalps.testing.storage.storage_test_case import (
    StorageTestCaseSpecification,
    build_case_from_parameters,
)
from ethos_penalps.testing.storage.storage_test_case_io import save_storage_test_case
from ethos_penalps.testing.stream.stream_group_test_case import (
    StreamGroupTestCaseSpecification,
)
from ethos_penalps.testing.stream.stream_test_case import (
    BatchStreamStateParams as B,
)
from ethos_penalps.testing.stream.stream_test_case import (
    BatchStreamTestCaseSpecification,
    ContinuousStreamTestCaseSpecification,
)
from ethos_penalps.testing.stream.stream_test_case import (
    ContinuousStreamStateParams as C,
)

CASES_DIR = os.path.join(os.path.dirname(os.path.abspath("__file__")), "cases")
T0 = datetime.datetime(2024, 1, 1)

# %% [markdown]
# ## Batch input — level_0
#
# Batch input only, start_storage_level=0.

# %%
params = StorageTestCaseSpecification(
    name="batch_input_level_0",
    description="Batch input only, start_storage_level=0.",
    start_time=T0,
    start_storage_level=0,
    input_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            BatchStreamTestCaseSpecification(
                states=[B(mass=50, gap_seconds=7200), B(mass=80, gap_seconds=7200)],
                start_offset_seconds=3600,
                batch_delay_seconds=3600,
                max_batch_mass=100,
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'batch_input_level_0', Entries: 5, In: 1 BatchStream, Out: none, Start level: 0.0, Min level: 0.0, End level: 130.0
# Saved case 'batch_input_level_0' to /fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_input_level_0/
#   expected_storage_entries.csv             0.3 KB
#   input_streams.csv                        0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_input_level_0'

# %% [markdown]
# ## Batch input — level_250
#
# Batch input only, start_storage_level=250.

# %%
params = StorageTestCaseSpecification(
    name="batch_input_level_250",
    description="Batch input only, start_storage_level=250.",
    start_time=T0,
    start_storage_level=250,
    input_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            BatchStreamTestCaseSpecification(
                states=[B(mass=50, gap_seconds=7200), B(mass=80, gap_seconds=7200)],
                start_offset_seconds=3600,
                batch_delay_seconds=3600,
                max_batch_mass=100,
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'batch_input_level_250', Entries: 5, In: 1 BatchStream, Out: none, Start level: 250.0, Min level: 250.0, End level: 380.0
# Saved case 'batch_input_level_250' to /fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_input_level_250/
#   expected_storage_entries.csv             0.3 KB
#   input_streams.csv                        0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_input_level_250'

# %% [markdown]
# ## Batch input — auto_offset
#
# Batch input only, auto_offset. Computed start is 0.

# %%
params = StorageTestCaseSpecification(
    name="batch_input_auto_offset",
    description="Batch input only, auto_offset. Computed start is 0.",
    start_time=T0,
    start_storage_level="auto_offset",
    input_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            BatchStreamTestCaseSpecification(
                states=[B(mass=50, gap_seconds=7200), B(mass=80, gap_seconds=7200)],
                start_offset_seconds=3600,
                batch_delay_seconds=3600,
                max_batch_mass=100,
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'batch_input_auto_offset', Entries: 5, In: 1 BatchStream, Out: none, Start level: 0.0, Min level: 0.0, End level: 130.0
# Saved case 'batch_input_auto_offset' to /fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_input_auto_offset/
#   expected_storage_entries.csv             0.3 KB
#   input_streams.csv                        0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_input_auto_offset'

# %% [markdown]
# ## Batch output — level_0
#
# Batch output only, start_storage_level=0. Level goes negative.

# %%
params = StorageTestCaseSpecification(
    name="batch_output_level_0",
    description="Batch output only, start_storage_level=0. Level goes negative.",
    start_time=T0,
    start_storage_level=0,
    output_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            BatchStreamTestCaseSpecification(
                states=[B(mass=50, gap_seconds=7200), B(mass=80, gap_seconds=7200)],
                start_offset_seconds=3600,
                batch_delay_seconds=3600,
                max_batch_mass=100,
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'batch_output_level_0', Entries: 5, In: none, Out: 1 BatchStream, Start level: 0.0, Min level: -130.0, End level: -130.0
# Saved case 'batch_output_level_0' to /fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_output_level_0/
#   expected_storage_entries.csv             0.3 KB
#   output_streams.csv                       0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_output_level_0'

# %% [markdown]
# ## Batch output — level_250
#
# Batch output only, start_storage_level=250. Level goes negative.

# %%
params = StorageTestCaseSpecification(
    name="batch_output_level_250",
    description="Batch output only, start_storage_level=250. Level goes negative.",
    start_time=T0,
    start_storage_level=250,
    output_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            BatchStreamTestCaseSpecification(
                states=[B(mass=50, gap_seconds=7200), B(mass=80, gap_seconds=7200)],
                start_offset_seconds=3600,
                batch_delay_seconds=3600,
                max_batch_mass=100,
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'batch_output_level_250', Entries: 5, In: none, Out: 1 BatchStream, Start level: 250.0, Min level: 120.0, End level: 120.0
# Saved case 'batch_output_level_250' to /fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_output_level_250/
#   expected_storage_entries.csv             0.3 KB
#   output_streams.csv                       0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_output_level_250'

# %% [markdown]
# ## Batch output — auto_offset
#
# Batch output only, auto_offset. Computed start equals total output mass.

# %%
params = StorageTestCaseSpecification(
    name="batch_output_auto_offset",
    description="Batch output only, auto_offset. Computed start equals total output mass.",
    start_time=T0,
    start_storage_level="auto_offset",
    output_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            BatchStreamTestCaseSpecification(
                states=[B(mass=50, gap_seconds=7200), B(mass=80, gap_seconds=7200)],
                start_offset_seconds=3600,
                batch_delay_seconds=3600,
                max_batch_mass=100,
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'batch_output_auto_offset', Entries: 5, In: none, Out: 1 BatchStream, Start level: 130.0, Min level: 0.0, End level: 0.0
# Saved case 'batch_output_auto_offset' to /fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_output_auto_offset/
#   expected_storage_entries.csv             0.3 KB
#   output_streams.csv                       0.2 KB
#   parameters.json                          0.7 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/02_single_batch_stream/cases/batch_output_auto_offset'
