# %% [markdown]
# # Single Continuous Stream
#
# One-directional continuous flows. Storage changes monotonically.
# Varies: direction (input/output) × storage level (0, 250, auto_offset).

# %%
import datetime
import os

# %load_ext autoreload
# %autoreload 2

from ethos_penalps.stream import StreamType
from ethos_penalps.testing.storage.storage_test_case import (
    StorageTestCaseSpecification,
    build_case_from_parameters,
)
from ethos_penalps.testing.storage.storage_test_case_io import save_storage_test_case
from ethos_penalps.testing.stream.stream_group_test_case import (
    StreamGroupTestCaseSpecification,
)
from ethos_penalps.testing.stream.stream_test_case import (
    BatchStreamStateParams as B,
)
from ethos_penalps.testing.stream.stream_test_case import (
    BatchStreamTestCaseSpecification,
    ContinuousStreamTestCaseSpecification,
)
from ethos_penalps.testing.stream.stream_test_case import (
    ContinuousStreamStateParams as C,
)

CASES_DIR = os.path.join(os.path.dirname(os.path.abspath("__file__")), "cases")
T0 = datetime.datetime(2024, 1, 1)

# %% [markdown]
# ## Continuous input — level_0
#
# Continuous input only, start_storage_level=0.

# %%
params = StorageTestCaseSpecification(
    name="continuous_input_level_0",
    description="Continuous input only, start_storage_level=0.",
    start_time=T0,
    start_storage_level=0,
    input_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            ContinuousStreamTestCaseSpecification(
                states=[
                    C(mass=100, rate=10, duration_seconds=3600),
                    C(mass=200, rate=10, duration_seconds=7200),
                ]
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'continuous_input_level_0', Entries: 3, In: 1 ContinuousStream, Out: none, Start level: 0.0, Min level: 0.0, End level: 300.0
# Saved case 'continuous_input_level_0' to /fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_input_level_0/
#   expected_storage_entries.csv             0.2 KB
#   input_streams.csv                        0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_input_level_0'

# %% [markdown]
# ## Continuous input — level_250
#
# Continuous input only, start_storage_level=250.

# %%
params = StorageTestCaseSpecification(
    name="continuous_input_level_250",
    description="Continuous input only, start_storage_level=250.",
    start_time=T0,
    start_storage_level=250,
    input_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            ContinuousStreamTestCaseSpecification(
                states=[
                    C(mass=100, rate=10, duration_seconds=3600),
                    C(mass=200, rate=10, duration_seconds=7200),
                ]
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'continuous_input_level_250', Entries: 3, In: 1 ContinuousStream, Out: none, Start level: 250.0, Min level: 250.0, End level: 550.0
# Saved case 'continuous_input_level_250' to /fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_input_level_250/
#   expected_storage_entries.csv             0.2 KB
#   input_streams.csv                        0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_input_level_250'

# %% [markdown]
# ## Continuous input — auto_offset
#
# Continuous input only, auto_offset. Computed start is 0.

# %%
params = StorageTestCaseSpecification(
    name="continuous_input_auto_offset",
    description="Continuous input only, auto_offset. Computed start is 0.",
    start_time=T0,
    start_storage_level="auto_offset",
    input_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            ContinuousStreamTestCaseSpecification(
                states=[
                    C(mass=100, rate=10, duration_seconds=3600),
                    C(mass=200, rate=10, duration_seconds=7200),
                ]
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'continuous_input_auto_offset', Entries: 3, In: 1 ContinuousStream, Out: none, Start level: 0.0, Min level: 0.0, End level: 300.0
# Saved case 'continuous_input_auto_offset' to /fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_input_auto_offset/
#   expected_storage_entries.csv             0.2 KB
#   input_streams.csv                        0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_input_auto_offset'

# %% [markdown]
# ## Continuous output — level_0
#
# Continuous output only, start_storage_level=0. Level goes negative.

# %%
params = StorageTestCaseSpecification(
    name="continuous_output_level_0",
    description="Continuous output only, start_storage_level=0. Level goes negative.",
    start_time=T0,
    start_storage_level=0,
    output_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            ContinuousStreamTestCaseSpecification(
                states=[
                    C(mass=100, rate=10, duration_seconds=3600),
                    C(mass=200, rate=10, duration_seconds=7200),
                ]
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'continuous_output_level_0', Entries: 3, In: none, Out: 1 ContinuousStream, Start level: 0.0, Min level: -280.0, End level: -300.0
# Saved case 'continuous_output_level_0' to /fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_output_level_0/
#   expected_storage_entries.csv             0.2 KB
#   output_streams.csv                       0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_output_level_0'

# %% [markdown]
# ## Continuous output — level_250
#
# Continuous output only, start_storage_level=250. Level goes negative.

# %%
params = StorageTestCaseSpecification(
    name="continuous_output_level_250",
    description="Continuous output only, start_storage_level=250. Level goes negative.",
    start_time=T0,
    start_storage_level=250,
    output_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            ContinuousStreamTestCaseSpecification(
                states=[
                    C(mass=100, rate=10, duration_seconds=3600),
                    C(mass=200, rate=10, duration_seconds=7200),
                ]
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'continuous_output_level_250', Entries: 3, In: none, Out: 1 ContinuousStream, Start level: 250.0, Min level: -30.0, End level: -50.0
# Saved case 'continuous_output_level_250' to /fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_output_level_250/
#   expected_storage_entries.csv             0.2 KB
#   output_streams.csv                       0.2 KB
#   parameters.json                          0.6 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_output_level_250'

# %% [markdown]
# ## Continuous output — auto_offset
#
# Continuous output only, auto_offset. Computed start equals total output mass.

# %%
params = StorageTestCaseSpecification(
    name="continuous_output_auto_offset",
    description="Continuous output only, auto_offset. Computed start equals total output mass.",
    start_time=T0,
    start_storage_level="auto_offset",
    output_stream_group=StreamGroupTestCaseSpecification(
        stream_specifications=[
            ContinuousStreamTestCaseSpecification(
                states=[
                    C(mass=100, rate=10, duration_seconds=3600),
                    C(mass=200, rate=10, duration_seconds=7200),
                ]
            )
        ]
    ),
    expect_full_mass_conservation=False,
)

case = build_case_from_parameters(params)
case.print_overview()
save_storage_test_case(case, CASES_DIR)
# Out:
# 'continuous_output_auto_offset', Entries: 3, In: none, Out: 1 ContinuousStream, Start level: 300.0, Min level: 20.0, End level: 0.0
# Saved case 'continuous_output_auto_offset' to /fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_output_auto_offset/
#   expected_storage_entries.csv             0.2 KB
#   output_streams.csv                       0.2 KB
#   parameters.json                          0.7 KB
# '/fast/home/j-belina/ethos_penalps/test/generate/storage/01_single_continuous_stream/cases/continuous_output_auto_offset'
